# %%
import matplotlib.pyplot as plt

# %%
plt.subplots(2,2)
plt.show()

# %%
import numpy as np
x=np.array([20,40,58,70,60])
y=np.array([30,35,55,80,50])
plt.subplot(2,2,1)
plt.plot(x,y,'r*',label="first row first column")
plt.legend()
plt.subplot(2,2,2)
plt.plot(x,y,'g^',label="first row second column")
plt.legend()
plt.subplot(2,2,3)
plt.plot(x,y,'c+',label="second row first column")
plt.legend()
plt.subplot(2,2,4)
plt.plot(x,y,'k--',label="second row second column")
plt.legend()
plt.show()

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin embarked
# ...

# %%
x=np.array([20,40,58,70,60])
y=np.array([30,35,55,80,50])
plt.subplot(2,2,1)
plt.plot(x,y,'r*',label="first row first column")
plt.legend()
plt.subplot(2,2,2)
plt.plot(x,y,'g^',label="first row second column")
plt.legend()
plt.subplot(2,2,3)
plt.plot(x,y,'c+',label="second row first column")
plt.legend()
plt.subplot(2,2,4)
plt.plot(x,y,'k--',label="second row second column")
df.embarked.value_counts().plot(kind='bar',alpha=0.5)
plt.legend()
plt.show()

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# cabin       687
# embarked      2
# dtype: int64

# %%
df.drop('cabin',axis=1,inplace=True)
df
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare embarked
# ...

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# name          0
# sex           0
# age         177
# sibsp         0
# parch         0
# ticket        0
# fare          0
# embarked      2
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    2
# dtype: int64

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
(df['embarked']=='S')
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888     True
# 889    False
# 890    False
# Name: embarked, Length: 891, dtype: bool

# %%
df['embarked'].fillna('S',inplace=True)

# %%
df.isnull().sum()
# Out:
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        0
# embarked    0
# dtype: int64

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       891 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
pd.get_dummies(df['embarked'])
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['embarked']=le.fit_transform(df['embarked'])
df['embarked']
# Out:
# 0      2
# 1      0
# 2      2
# 3      2
# 4      2
#       ..
# 886    2
# 887    2
# 888    2
# 889    0
# 890    1
# Name: embarked, Length: 891, dtype: int32

# %%
 df['embarked'].unique()
# Out:
# array([2, 0, 1])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       891 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   embarked  891 non-null    int32
# dtypes: float64(2), int32(1), int64(4), object(3)
# memory usage: 66.3+ KB

# %% [markdown]
# # scalling techinques
# ## 1.minmax scalar
# ## 2.robust scalar
# ## 3.standaization
# ## 4.normalization

# %%
df['sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: sex, Length: 891, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax=MinMaxScaler()

# %%
'''xi-Min(x)
--------           ##formula
min(x)-max(x)
'''
df.drop('name',axis=1,inplace=True)

# %%
df.drop('ticket',axis=1,inplace=True)

# %%
df2=minmax.fit_transform(df)
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-ffbb715c235d> in <module>
# ----> 1 df2=minmax.fit_transform(df)
#       2 df2
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     334         # Reset internal state before fitting
#     335         self._reset()
# --> 336         return self.partial_fit(X, y)
#     337
#     338     def partial_fit(self, X, y=None):
#
# ...

# %%
'vamsi'

# %%
'veeranji'

# %%
from sklearn.preprocessing import Normalizer

# %%
nr=Normalizer()

# %%
df2=nr.fit_transform(df)

# %% [markdown]
# ## Seaborn
# - https://seaborn.pydata.org
# - Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - matplotlib
# - seaborn
# - bokeh
# ## visualisation tools
# - tableu
# - SAS
# - power blue

# %% [markdown]
# ## seaborn Styles
# - catagorical scatter plots
#      - strip plot
#      - swarm plot
# - catagorical distribution plots
#      - box plot
#      - voilin plot
# - catagorical continues plots
#      - count plot
#      - point plot
#      - etc..

# %%
pip install seaborn

# %%
import seaborn as sns

# %%
dir(sns)

# %%
## seaborn styles are white,dark,whitegrid,darkgrid,ticks.
sns.set_style('ticks')

# %%
## inbuilt datasets 
sns.get_dataset_names()

# %%
df=sns.load_dataset('iris')
df.head()

# %%
df.columns

# %%
df['species']

# %%
df['species'].value_counts()

# %%
df.groupby('weight').count()

# %% [markdown]
# ## seaborn plot

# %%
df.plot()

# %%
df.plot(kind='box')

# %%
df.plot(kind='bar')

# %%
df.plot(kind='hist')

# %%
sns.color_palette() ## to know the colors in sns

# %%
sns.color_palette(n_colors=5)

# %%
sns.color_palette('BuGn')

# %%
sns.color_palette('PuBu')

# %%
sns.palplot('c',size=2)

# %%
sns.cubehelix_palette()

# %%
sns.cubehelix_palette(n_colors=3)

# %%
sns.cubehelix_palette(n_colors=7,reverse=True)

# %%
sns.cubehelix_palette(n_colors=7,reverse=True,hue=2)

# %%
sns.cubehelix_palette(n_colors=7,reverse=True,hue=3)

# %%
sns.cubehelix_palette(n_colors=7,reverse=True,hue=4)

# %%
sns.cubehelix_palette(n_colors=7,reverse=True,hue=10)

# %%
sns.cubehelix_palette(n_colors=7,reverse=True,hue=0.2)

# %%
## creating custom colot palette
sns.light_palette('green')

# %%
sns.light_palette('orange')

# %%
sns.light_palette('pink')

# %%
sns.dark_palette('green')

# %%
sns.dark_palette('pink')

# %%
sns.dark_palette('orange',n_colors=10)

# %%
sns.dark_palette('purple',n_colors=10)

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
## catplot
import seaborn as sns
help(sns.catplot)
# Out:
# Help on function catplot in module seaborn.categorical:
#
# catplot(*, x=None, y=None, hue=None, data=None, row=None, col=None, col_wrap=None, estimator=<function mean at 0x00000233CD522AF0>, ci=95, n_boot=1000, units=None, seed=None, order=None, hue_order=None, row_order=None, col_order=None, kind='strip', height=5, aspect=1, orient=None, color=None, palette=None, legend=True, legend_out=True, sharex=True, sharey=True, margin_titles=False, facet_kws=None, **kwargs)
#     Figure-level interface for drawing categorical plots onto a
#     :class:`FacetGrid`.
#
#     This function provides access to several axes-level functions that
#     show the relationship between a numerical and one or more categorical
#     variables using one of several visual representations. The ``kind``
#     parameter selects the underlying axes-level function to use:
#
#     Categorical scatterplots:
#
#     - :func:`stripplot` (with ``kind="strip"``; the default)
# ...

# %%
sns.catplot(data=df)

# %%
df=pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.catplot(data=df)

# %%
sns.catplot(x="Species",y="SepalLengthCm",data=df,hue="PetalWidthCm")

# %%
sns.catplot(x="Species",y="SepalLengthCm",data=df,hue="Species",kind="swarm")

# %%
sns.catplot(x="SepalWidthCm",y="Species",data=df,hue="Species",kind="box")

# %%
sns.catplot(x="PetalLengthCm",y="Species",data=df,col="Species",kind="violin")

# %%
sns.catplot(x="PetalLengthCm",y="PetalWidthCm",data=df,hue="Species",palette=['r','g','b'])

# %%
sns.catplot(x="PetalLengthCm",y="PetalWidthCm",data=df,hue="Species",palette=['r','g','b'],marker='*')

# %%
df1=sns.load_dataset("tips")
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## box plot

# %%
df1.plot() ## it takes integer data columns
# Out:
# <AxesSubplot:>

# %%
sns.boxplot()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='day',y='tip',data=df1)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='day',y='tip',data=df1,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.boxplot(x='total_bill',y='time',data=df1)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %%
sns.boxplot(x='total_bill',y='time',data=df1,hue='smoker',orient='h')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %%
sns.boxplot(x='total_bill',y='time',data=df1,hue='smoker',orient='h')
sns.swarmplot(x='total_bill',y='time',data=df1,hue='smoker',color='purple')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='time'>

# %% [markdown]
# ## violin plot
# - combination of box plot and kernel destination polt
# - syntax=sns.violinplot()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df3=sns.load_dataset('dots')

# %%
df3.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',split=True)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice')
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',dodge=True)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',dodge=False)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',dodge=False)
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',split=True)
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',inner='quartile')
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %%
sns.violinplot(x="align",y="firing_rate",data=df3,hue='choice',inner='stick')
# Out:
# <AxesSubplot:xlabel='align', ylabel='firing_rate'>

# %% [markdown]
# ## kde
# - kernal density estimator plot
# - used for observing distribution data
# - important method sns.kdeplot()

# %%
df3
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.kdeplot(x='firing_rate',data=df3)  ## it takes only one value
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='Density'>

# %%
sns.set_style("darkgrid")
sns.kdeplot(x='firing_rate',data=df3)
sns.set_context("paper")

# %%
sns.set_style("darkgrid")
sns.kdeplot(x='firing_rate',data=df3)
sns.set_context("poster")

# %% [markdown]
# ## joint plot
# - joins different plots together
# - sns.jointplot()

# %%
sns.jointplot(x='firing_rate',y="coherence",data=df3,hue='time') ##when take joint x&y must be integer

# %%
sns.jointplot(x='firing_rate',y="coherence",data=df3,kind='reg')

# %%
sns.jointplot(x='firing_rate',y="coherence",data=df3,kind='hist')

# %%
sns.jointplot(x='firing_rate',y="coherence",data=df3,kind='hex')

# %%
sns.jointplot(x='firing_rate',y="coherence",data=df3,kind='resid')

# %% [markdown]
# ## pair plot
# - it displays (a relationship between a data
# - sns.pairplot()

# %%
sns.pairplot(data=df3)

# %%
sns.pairplot(data=df3,hue='choice')

# %%
df3["choice"].value_counts()
# Out:
# T2    430
# T1    418
# Name: choice, dtype: int64

# %% [markdown]
# ## barplot
# - sns.bar()

# %%
sns.barplot(x="firing_rate",y="choice",data=df3,hue="align")
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %%
import numpy as np
sns.barplot(x="firing_rate",y="choice",data=df3,hue="align",estimator=np.std)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %%
sns.barplot(x="firing_rate",y="choice",data=df3,hue="align",estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %%
sns.barplot(x="firing_rate",y="choice",data=df3,hue="align",estimator=np.median)
# Out:
# <AxesSubplot:xlabel='firing_rate', ylabel='choice'>

# %% [markdown]
# ## correlation
# corr=df.corr()
# - (-1 negatively correlate,1 high correlated)

# %%
df.head()
corr=df.corr()

# %%
sns.pointplot(x="SepalLengthCm",y='Species',data=df,join=False)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Species'>
